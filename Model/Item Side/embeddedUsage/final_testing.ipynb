# %%
import pickle
import marshal
import types
import transformers
import torch

# Device= 'cuda' if torch.cuda.is_available() else 'cpu' 
my_model = pickle.load(open("./embed_model.pkl", 'rb'))
my_tokenizer= pickle.load( open("./embed_tokenizer.pkl", 'rb') )
my_cosine= pickle.load(open("./embed_cosine.pkl", 'rb') )
my_pca= pickle.load(open("./embed_pca.pkl", 'rb') )
my_embed= pickle.load(open("./embed_embeddings.pkl", 'rb') )
my_train_sample= pickle.load(open("./embed_train_sample.pkl", 'rb') )

with open("./embed_find_similar_questions.mar", 'rb') as f:
  my_sim_code= marshal.load(f)

with open("./embed_get_embedding.mar", 'rb') as f:
  my_get_embed_code= marshal.load(f)

my_sim= types.FunctionType(my_sim_code, globals(), "my_sim")
my_get_embed= types.FunctionType(my_get_embed_code, globals(), "my_get_embed" )

# %%
input_question = "sort a list in python"
my_sim(input_question, my_tokenizer, my_model, my_pca, my_cosine, my_embed, my_get_embed, 'cpu',my_train_sample,  20 )
# Out:
#                                                    name
# 628   Count Unique Characters of All Substrings of a...
# 897   Compare Strings by Frequency of the Smallest C...
# 2348  Lexicographically Minimum String After Removin...
# 2027                       Extra Characters in a String
# 705                                       Sort an Array
# 1717                               Design a Text Editor
# 1109                             Design Browser History
# 1232      Count Substrings That Differ by One Character
# 916                                     Design Skiplist
# 1490          Find the Kth Largest Integer in the Array
# 530                                      Design HashMap
# 273                                      Design Twitter
# 1920                 Subsequence With the Minimum Score
# 2183  Number of Strings Which Can Be Rearranged to C...
# 187                        Implement Trie (Prefix Tree)
# 595                     Number of Matching Subsequences
# ...
